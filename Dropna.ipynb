# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/Mental Health Dataset.csv')

# %%
df.shape
# Out:
# (292364, 17)

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       0
# care_options                  0
# dtype: int64

# %%
columns_to_drop=["Timestamp","Country","care_options"]
df=df.drop(columns=[col for col in columns_to_drop if col in df.columns],errors ='ignore')

# %%
df.shape
# Out:
# (292364, 14)

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       0
# dtype: int64

# %%
df.dropna(how='all')
# Out:
#         Gender Occupation self_employed family_history treatment Days_Indoors  \
# 0       Female  Corporate           NaN             No       Yes    1-14 days
# 1       Female  Corporate           NaN            Yes       Yes    1-14 days
# 2       Female  Corporate           NaN            Yes       Yes    1-14 days
# 3       Female  Corporate            No            Yes       Yes    1-14 days
# 4       Female  Corporate            No            Yes       Yes    1-14 days
# ...        ...        ...           ...            ...       ...          ...
# 292359    Male   Business           Yes            Yes       Yes   15-30 days
# 292360    Male   Business            No            Yes       Yes   15-30 days
# 292361    Male   Business            No            Yes        No   15-30 days
# 292362    Male   Business            No            Yes       Yes   15-30 days
# 292363    Male   Business            No            Yes       Yes   15-30 days
#
#        Growing_Stress Changes_Habits Mental_Health_History Mood_Swings  \
# 0                 Yes             No                   Yes      Medium
# 1                 Yes             No                   Yes      Medium
# 2                 Yes             No                   Yes      Medium
# 3                 Yes             No                   Yes      Medium
# 4                 Yes             No                   Yes      Medium
# ...               ...            ...                   ...         ...
# 292359             No          Maybe                    No         Low
# 292360             No          Maybe                    No         Low
# 292361             No          Maybe                    No         Low
# 292362             No          Maybe                    No         Low
# 292363             No          Maybe                    No         Low
#
#        Coping_Struggles Work_Interest Social_Weakness mental_health_interview
# 0                    No            No             Yes                      No
# 1                    No            No             Yes                      No
# 2                    No            No             Yes                      No
# 3                    No            No             Yes                   Maybe
# 4                    No            No             Yes                      No
# ...                 ...           ...             ...                     ...
# 292359              Yes            No           Maybe                   Maybe
# 292360              Yes            No           Maybe                      No
# 292361              Yes            No           Maybe                      No
# 292362              Yes            No           Maybe                      No
# 292363              Yes            No           Maybe                      No
#
# [292364 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                     0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# dtype: int64
